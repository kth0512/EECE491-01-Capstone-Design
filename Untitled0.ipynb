# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ⚠️⚠️⚠️ '/content/drive/...' 경로는 본인 경로로 수정하세요
# %cd /content/drive/MyDrive/commit_test_folder/EECE491-01-Capstone-Design
# Out:
# /content/drive/MyDrive/commit_test_folder/EECE491-01-Capstone-Design

# %%
# !git config --global user.email 'kth0512@postech.ac.kr'
# !git config --global user.name 'kth0512'

# %%
# 1. "__pycache__/"라는 텍스트를 .gitignore 파일에 추가합니다.
# !echo "__pycache__/" >> .gitignore

# 2. 새로 만든 .gitignore 파일을 Git에 추가합니다.
# !git add .gitignore

# 3. "chore: gitignore에 pycache 추가"라는 메시지로 커밋합니다.
# !git commit -m "chore: Add __pycache__ to .gitignore"
# Out:
# [main fe1cde3] chore: Add __pycache__ to .gitignore
#  10 files changed, 2 insertions(+)
#  create mode 100644 .gitignore
#  delete mode 100644 __pycache__/FaceDetector.cpython-312.pyc
#  delete mode 100644 __pycache__/celeba_dataset.cpython-312.pyc
#  delete mode 100644 __pycache__/channels.cpython-312.pyc
#  delete mode 100644 __pycache__/data_utils.cpython-312.pyc
#  delete mode 100644 __pycache__/face_autoencoder.cpython-312.pyc
#  delete mode 100644 __pycache__/face_detector.cpython-312.pyc
#  delete mode 100644 __pycache__/io_utils.cpython-312.pyc
#  delete mode 100644 __pycache__/utils.cpython-312.pyc
#  delete mode 100644 __pycache__/viz_utils.cpython-312.pyc

# %%
# 1. Git 추적 목록(캐시)에서 __pycache__ 폴더를 삭제합니다.
# (실제 폴더는 삭제되지 않습니다.)
# !git rm -r --cached __pycache__

# 2. 캐시에서 삭제된 내역을 커밋합니다.
# !git commit -m "chore: Remove tracked __pycache__ files"
# Out:
# fatal: pathspec '__pycache__' did not match any files
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Untitled0.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git push
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 374 bytes | 31.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/kth0512/EECE491-01-Capstone-Design.git
#    8bd1e1e..fe1cde3  main -> main
